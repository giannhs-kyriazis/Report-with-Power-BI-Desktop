# %% [markdown]
# <a href="https://colab.research.google.com/github/giannhs-kyriazis/Report-with-Power-BI-Desktop/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/diploma thesis data.xlsx")

# %%
import yfinance as yf

# Λήψη δεδομένων
dates = ["2023-12-15", "2024-05-31"]
data = yf.download("^DJI", start="2023-12-14", end="2024-06-01")

# Εμφάνιση τιμών κλεισίματος
print(data.loc[dates, 'Close'])
# Out:
# /tmp/ipython-input-241257823.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("^DJI", start="2023-12-14", end="2024-06-01")
# [*********************100%***********************]  1 of 1 completed
# Ticker              ^DJI
# Date
# 2023-12-15  37305.160156
# 2024-05-31  38686.320312

# %%
start_amount=10000

# %%
final_amount=start_amount*(38686.320312-37305.160156)/1000

# %%
print(final_amount)
# Out:
# 13811.601560000054
